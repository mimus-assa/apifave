# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import models
from tensorflow.keras import backend as k
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
import json
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
import numpy as np
from os import listdir
from tensorflow.keras.preprocessing.image import img_to_array
from shutil import copyfile
import os

# %%
model_dir = '/home/mimus/apifave/models/dl/anplr_t9921_gray_34ch.h5'
model = models.load_model(model_dir)
with open('/home/mimus/apifave/dict_ocr_34.json', 'r') as f:
    labels = json.load(f)
letters = list(labels)
try:
    for l in letters:
        os.mkdir("/home/mimus/apiais/data/images/ANPR/training/letters_gray/"+l)
except:
    pass
characters = [l for l in listdir('/home/mimus/apiais/data/images/ANPR/training/letters/a/')]
predos = []
for each_character in characters:
    img = load_img('/home/mimus/apiais/data/images/ANPR/training/letters/a/'+each_character, color_mode = "grayscale", target_size = (20,40))
    img_array = img_to_array(img)
    img_array = img_array.reshape(1, 20, 40, 1).astype('float')
    results = model.predict_classes(img_array, batch_size=1)
    dst = '/home/mimus/apiais/data/images/ANPR/training/letters_gray/'+letters[results[0]]+'/'+each_character
    copyfile('/home/mimus/apiais/data/images/ANPR/training/letters/a/'+each_character, dst)
    #print(dst)
    print(each_character, str(letters[results[0]]))
# Out:
# WARNING:tensorflow:From <ipython-input-2-6306dcb53d44>:17: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# letter_1073_22.jpg 1
# letter_2043_40.jpg 2
# letter_1146_27.jpg A
# letter_967_38.jpg 6
# letter_751_34.jpg D
# letter_32_36.jpg 4
# letter_1780_33.jpg 0
# letter_1977_0_3.jpg 3
# letter_1379_33.jpg 5
# letter_1686_41.jpg 1
# letter_275_22.jpg G
# letter_1466_22.jpg 0
# letter_1171_41.jpg 1
# letter_635_39.jpg V
# letter_34_19.jpg 1
# letter_683_4.jpg 1
# letter_1071_30.jpg B
# letter_2150_40.jpg 3
# letter_290_38.jpg G
# letter_351_42.jpg 9
# letter_1425_32.jpg G
# ...

# %%
print(results)
# Out:
# [13  0  4 18  5 16  9 18 18  4 16  1 16  1 28 16 18  9  4  1  0  0 18  1
#  16 21 22  4 21  9 18  4 26 21  0 16 18  5  3  9 21 21  1 18 18 16  9 21
#   1 18 18 18 18 18 16  9  1  9  1 18 21 18  1 21  1  1 18  9  0 16  0 21
#   4  1  9 18  4  0 18  0 18  0  3  1 26  9 21  1  9  1 16 21  3 21  1  1
#  16  0 18  0 18 18 18 18  4 18 21 18  1 18  1  0 16 13  2 18  3 26 18 16
#  16 16  4 18 28  5 18  3  0 18 18  1  1 20  4 21  9 18 18  1  1  0 18  0
#   1  0 18 18 20 18 21 26 18  1 18  1  1  1 18 16  4 18 18 19 21  4 18  3
#  16 15  9 18 16 26  0 18  1 21  3  1  1  1  0 21 18  1 18 16 21  4 21  1
#   1 22 16 16 26 21 30 29 22 21 18  0 16  2 26  0 21 18  9 18 20 16  0 18
#   9  9 21 18  1  0  4 29 16  1 18 21  5 21  5 16 18  1  0  4  1  3 18  1
#  21  0  1  4  0  1 18 16 18  4 23  1 18  9 20  1 18 18  1 18 21  9 18  1
#  18  4 16 18  4 16  1 16 18 29  1 18 18 29  1  5 18 16  3  1  3 18  0 18
#   1  1 16 18 18 16 18  1  1 20  0  1  1 21 18 16 21  1 16  3  4 21 18  0
# ...

# %%
k = 0
for result in results:
    
    results2 = [str(letters[result])]
    print(file_name[k], results2[0])
    k +=1
# Out:
# a/letter_0.jpg D
# a/letter_1.jpg 0
# a/letter_10.jpg 4
# a/letter_100.jpg J
# a/letter_101.jpg 5
# a/letter_102.jpg G
# a/letter_103.jpg 9
# a/letter_104.jpg J
# a/letter_105.jpg J
# a/letter_106.jpg 4
# a/letter_107.jpg G
# a/letter_108.jpg 1
# a/letter_109.jpg G
# a/letter_11.jpg 1
# a/letter_110.jpg V
# a/letter_111.jpg G
# a/letter_112.jpg J
# a/letter_113.jpg 9
# a/letter_114.jpg 4
# a/letter_115.jpg 1
# a/letter_116.jpg 0
# a/letter_117.jpg 0
# a/letter_118.jpg J
# a/letter_119.jpg 1
# a/letter_12.jpg G
# a/letter_120.jpg M
# a/letter_121.jpg N
# a/letter_122.jpg 4
# a/letter_123.jpg M
# a/letter_124.jpg 9
# a/letter_125.jpg J
# a/letter_126.jpg 4
# a/letter_127.jpg T
# a/letter_128.jpg M
# a/letter_129.jpg 0
# a/letter_13.jpg G
# a/letter_130.jpg J
# a/letter_131.jpg 5
# a/letter_132.jpg 3
# a/letter_133.jpg 9
# a/letter_134.jpg M
# a/letter_135.jpg M
# a/letter_136.jpg 1
# a/letter_137.jpg J
# a/letter_138.jpg J
# a/letter_139.jpg G
# a/letter_14.jpg 9
# a/letter_140.jpg M
# ...
